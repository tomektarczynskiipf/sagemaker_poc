# %%
# !pip install mlflow==2.13.2 sagemaker-mlflow==0.1.0
# Out:
# Requirement already satisfied: mlflow==2.13.2 in /opt/conda/lib/python3.10/site-packages (2.13.2)
# Requirement already satisfied: sagemaker-mlflow==0.1.0 in /opt/conda/lib/python3.10/site-packages (0.1.0)
# Requirement already satisfied: Flask<4 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (3.0.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.13.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (2.2.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (7.1.0)
# Requirement already satisfied: entrypoints<1 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (3.1.43)
# Requirement already satisfied: graphene<4 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (3.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (6.10.0)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (3.6)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (3.8.4)
# Requirement already satisfied: numpy<2 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.26.4)
# Requirement already satisfied: opentelemetry-api<3,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.25.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.25.0)
# Requirement already satisfied: packaging<25 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (23.2)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (2.1.4)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (4.24.4)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (15.0.0)
# Requirement already satisfied: pytz<2025 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (2023.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (6.0.1)
# Requirement already satisfied: querystring-parser<2 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.2.4)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (2.32.3)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.4.2)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.11.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (2.0.30)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (0.5.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (3.1.4)
# Requirement already satisfied: gunicorn<23 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (22.0.0)
# Requirement already satisfied: boto3>=1.34 in /opt/conda/lib/python3.10/site-packages (from sagemaker-mlflow==0.1.0) (1.34.131)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==2.13.2) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==2.13.2) (4.12.2)
# Requirement already satisfied: botocore<1.35.0,>=1.34.131 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.34->sagemaker-mlflow==0.1.0) (1.34.131)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.34->sagemaker-mlflow==0.1.0) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.34->sagemaker-mlflow==0.1.0) (0.10.2)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow==2.13.2) (1.26.19)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow==2.13.2) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow==2.13.2) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow==2.13.2) (1.8.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow==2.13.2) (4.0.11)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/conda/lib/python3.10/site-packages (from graphene<4->mlflow==2.13.2) (3.2.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/conda/lib/python3.10/site-packages (from graphene<4->mlflow==2.13.2) (3.2.0)
# Requirement already satisfied: aniso8601<10,>=8 in /opt/conda/lib/python3.10/site-packages (from graphene<4->mlflow==2.13.2) (9.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow==2.13.2) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow==2.13.2) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (2.9.0)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api<3,>=1.0.0->mlflow==2.13.2) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.0.0->mlflow==2.13.2) (0.46b0)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3->mlflow==2.13.2) (2024.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from querystring-parser<2->mlflow==2.13.2) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.13.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.13.2) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.13.2) (2024.6.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2->mlflow==2.13.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2->mlflow==2.13.2) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.13.2) (3.0.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.0.0->mlflow==2.13.2) (1.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow==2.13.2) (5.0.0)
# WARNING: Error parsing requirements for fsspec: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/fsspec-2023.6.0.dist-info/METADATA'

# %%
from functions import *

import boto3
import pandas as pd
import io
import mlflow
from mlflow.tracking import MlflowClient
from itertools import combinations
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score

settings = read_settings()

# %%
mlflow.set_tracking_uri(settings['mlflow_arn'])
mlflow.set_experiment(settings['mlflow_experiment_name'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 mlflow.set_tracking_uri(settings['mlflow_arn'])
# ----> 2 mlflow.set_experiment(settings['mlflow_experiment_name'])
#
# File /opt/conda/lib/python3.10/site-packages/mlflow/tracking/fluent.py:143, in set_experiment(experiment_name, experiment_id)
#     141 client = MlflowClient()
#     142 if experiment_id is None:
# --> 143     experiment = client.get_experiment_by_name(experiment_name)
#     144     if not experiment:
#     145         _logger.info(
#     146             "Experiment with name '%s' does not exist. Creating a new experiment.",
#     147             experiment_name,
#     148         )
#
# File /opt/conda/lib/python3.10/site-packages/mlflow/tracking/client.py:1230, in MlflowClient.get_experiment_by_name(self, name)
#    1198 def get_experiment_by_name(self, name: str) -> Optional[Experiment]:
#    1199     """Retrieve an experiment by experiment name from the backend store
#    1200
#    1201     Args:
#    (...)
#    1228         Lifecycle_stage: active
#    1229     """
# -> 1230     return self._tracking_client.get_experiment_by_name(name)
#
# File /opt/conda/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:481, in TrackingServiceClient.get_experiment_by_name(self, name)
#     473 def get_experiment_by_name(self, name):
#     474     """
#     475     Args:
#     476         name: The experiment name.
#    (...)
#     479         :py:class:`mlflow.entities.Experiment`
#     480     """
# --> 481     return self.store.get_experiment_by_name(name)
#
# File /opt/conda/lib/python3.10/site-packages/mlflow/store/tracking/rest_store.py:518, in RestStore.get_experiment_by_name(self, experiment_name)
#     516 try:
#     517     req_body = message_to_json(GetExperimentByName(experiment_name=experiment_name))
# --> 518     response_proto = self._call_endpoint(GetExperimentByName, req_body)
#     519     return Experiment.from_proto(response_proto.experiment)
#     520 except MlflowException as e:
#
# File /opt/conda/lib/python3.10/site-packages/mlflow/store/tracking/rest_store.py:81, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      79     endpoint, method = _METHOD_TO_INFO[api]
#      80 response_proto = api.Response()
# ---> 81 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File /opt/conda/lib/python3.10/site-packages/mlflow/utils/rest_utils.py:299, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     297 if method == "GET":
#     298     call_kwargs["params"] = json_body
# --> 299     response = http_request(**call_kwargs)
#     300 else:
#     301     call_kwargs["json"] = json_body
#
# File /opt/conda/lib/python3.10/site-packages/mlflow/utils/rest_utils.py:129, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     127 url = f"{cleaned_hostname}{endpoint}"
#     128 try:
# --> 129     return _get_http_response_with_retries(
#     130         method,
#     131         url,
#     132         max_retries,
#     133         backoff_factor,
#     134         backoff_jitter,
#     135         retry_codes,
#     136         raise_on_status,
#     137         headers=headers,
#     138         verify=host_creds.verify,
#     139         timeout=timeout,
#     140         respect_retry_after_header=respect_retry_after_header,
#     141         **kwargs,
#     142     )
#     143 except requests.exceptions.Timeout as to:
#     144     raise MlflowException(
#     145         f"API request to {url} failed with timeout exception {to}."
#     146         " To increase the timeout, set the environment variable "
#     147         f"{MLFLOW_HTTP_REQUEST_TIMEOUT!s} to a larger value."
#     148     ) from to
#
# File /opt/conda/lib/python3.10/site-packages/mlflow/utils/request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     234 env_value = os.getenv("MLFLOW_ALLOW_HTTP_REDIRECTS", "true").lower() in ["true", "1"]
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/conda/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/conda/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/connectionpool.py:896, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     894     retries.sleep(response)
#     895     log.debug("Retry: %s", url)
# --> 896     return self.urlopen(
#     897         method,
#     898         url,
#     899         body,
#     900         headers,
#     901         retries=retries,
#     902         redirect=redirect,
#     903         assert_same_host=assert_same_host,
#     904         timeout=timeout,
#     905         pool_timeout=pool_timeout,
#     906         release_conn=release_conn,
#     907         chunked=chunked,
#     908         body_pos=body_pos,
#     909         **response_kw
#     910     )
#     912 return response
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/connectionpool.py:896, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     894     retries.sleep(response)
#     895     log.debug("Retry: %s", url)
# --> 896     return self.urlopen(
#     897         method,
#     898         url,
#     899         body,
#     900         headers,
#     901         retries=retries,
#     902         redirect=redirect,
#     903         assert_same_host=assert_same_host,
#     904         timeout=timeout,
#     905         pool_timeout=pool_timeout,
#     906         release_conn=release_conn,
#     907         chunked=chunked,
#     908         body_pos=body_pos,
#     909         **response_kw
#     910     )
#     912 return response
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/connectionpool.py:896, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     894     retries.sleep(response)
#     895     log.debug("Retry: %s", url)
# --> 896     return self.urlopen(
#     897         method,
#     898         url,
#     899         body,
#     900         headers,
#     901         retries=retries,
#     902         redirect=redirect,
#     903         assert_same_host=assert_same_host,
#     904         timeout=timeout,
#     905         pool_timeout=pool_timeout,
#     906         release_conn=release_conn,
#     907         chunked=chunked,
#     908         body_pos=body_pos,
#     909         **response_kw
#     910     )
#     912 return response
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/connectionpool.py:894, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     891     return response
#     893 response.drain_conn()
# --> 894 retries.sleep(response)
#     895 log.debug("Retry: %s", url)
#     896 return self.urlopen(
#     897     method,
#     898     url,
#    (...)
#     909     **response_kw
#     910 )
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/util/retry.py:434, in Retry.sleep(self, response)
#     431     if slept:
#     432         return
# --> 434 self._sleep_backoff()
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/util/retry.py:418, in Retry._sleep_backoff(self)
#     416 if backoff <= 0:
#     417     return
# --> 418 time.sleep(backoff)
#
# KeyboardInterrupt:

# %%
# Read the train and validation data from S3
train_s3_key = f"{settings['project_path_s3']}/data/train/train.csv"
valid_s3_key = f"{settings['project_path_s3']}/data/valid/valid.csv"

train_df = read_csv_from_s3(settings['bucket_name'], train_s3_key)
valid_df = read_csv_from_s3(settings['bucket_name'], valid_s3_key)

# %%
def get_all_combinations(columns):
    """
    Get all possible combinations of columns for logistic regression models.

    Parameters:
    - columns: list, the list of column names

    Returns:
    - list of tuples, each tuple contains a combination of column names
    """
    combinations_list = []
    for r in range(1, len(columns) + 1):
        combinations_list.extend(combinations(columns, r))
    return combinations_list

# %%
def build_and_evaluate_models(train_df, valid_df, target_column):
    """
    Build and evaluate all possible logistic regression models.

    Parameters:
    - train_df: pd.DataFrame, the training dataset
    - valid_df: pd.DataFrame, the validation dataset
    - target_column: str, the name of the target column

    Returns:
    - list of tuples, each tuple contains model combination, train accuracy, valid accuracy, train AUC, and valid AUC
    """
    results = []
    feature_columns = [col for col in train_df.columns if col != target_column]
    combinations_list = get_all_combinations(feature_columns)

    for combination in combinations_list:
        with mlflow.start_run():
            model = LogisticRegression(max_iter=1000, random_state=42)
            model.fit(train_df[list(combination)], train_df[target_column])

            train_predictions = model.predict(train_df[list(combination)])
            valid_predictions = model.predict(valid_df[list(combination)])

            train_accuracy = accuracy_score(train_df[target_column], train_predictions)
            valid_accuracy = accuracy_score(valid_df[target_column], valid_predictions)

            train_auc = roc_auc_score(train_df[target_column], model.predict_proba(train_df[list(combination)])[:, 1])
            valid_auc = roc_auc_score(valid_df[target_column], model.predict_proba(valid_df[list(combination)])[:, 1])

            # Log parameters: which variables are used
            for col in feature_columns:
                mlflow.log_param(f"use_{col}", col in combination)

            # Log metrics
            mlflow.log_metric("train_accuracy", train_accuracy)
            mlflow.log_metric("valid_accuracy", valid_accuracy)
            mlflow.log_metric("train_auc", train_auc)
            mlflow.log_metric("valid_auc", valid_auc)

            mlflow.sklearn.log_model(model, "model")

            results.append((combination, train_accuracy, valid_accuracy, train_auc, valid_auc))

    return sorted(results, key=lambda x: x[3], reverse=True)  # Sort by valid AUC

# Ensure the target column is correctly specified
target_column = 'target'  # Change this if your target column has a different name

# Build and evaluate models
results = build_and_evaluate_models(train_df, valid_df, target_column)

# Print the results
for combination, train_acc, valid_acc, train_auc, valid_auc in results:
    print(f"Features: {combination}, Train Accuracy: {train_acc:.4f}, Valid Accuracy: {valid_acc:.4f}, Train AUC: {train_auc:.4f}, Valid AUC: {valid_auc:.4f}")
# Out:
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# ...
# Features: ('col_1', 'col_2', 'col_5', 'col_6'), Train Accuracy: 0.7213, Valid Accuracy: 0.7253, Train AUC: 0.7987, Valid AUC: 0.8023
# Features: ('col_5', 'col_6', 'col_7', 'col_8'), Train Accuracy: 0.7211, Valid Accuracy: 0.7180, Train AUC: 0.7980, Valid AUC: 0.7958
# Features: ('col_4', 'col_5', 'col_6', 'col_7', 'col_8'), Train Accuracy: 0.7210, Valid Accuracy: 0.7184, Train AUC: 0.7980, Valid AUC: 0.7958
# Features: ('col_6', 'col_7', 'col_8'), Train Accuracy: 0.7210, Valid Accuracy: 0.7184, Train AUC: 0.7980, Valid AUC: 0.7958
# Features: ('col_4', 'col_6', 'col_7', 'col_8'), Train Accuracy: 0.7209, Valid Accuracy: 0.7186, Train AUC: 0.7980, Valid AUC: 0.7958
# Features: ('col_3', 'col_4', 'col_5', 'col_7', 'col_8'), Train Accuracy: 0.7198, Valid Accuracy: 0.7208, Train AUC: 0.7975, Valid AUC: 0.7952
# Features: ('col_3', 'col_5', 'col_7', 'col_8'), Train Accuracy: 0.7198, Valid Accuracy: 0.7209, Train AUC: 0.7975, Valid AUC: 0.7952
# Features: ('col_3', 'col_7', 'col_8'), Train Accuracy: 0.7195, Valid Accuracy: 0.7205, Train AUC: 0.7975, Valid AUC: 0.7952
# Features: ('col_3', 'col_4', 'col_7', 'col_8'), Train Accuracy: 0.7197, Valid Accuracy: 0.7203, Train AUC: 0.7975, Valid AUC: 0.7952
# Features: ('col_1', 'col_4', 'col_5', 'col_6', 'col_7'), Train Accuracy: 0.7204, Valid Accuracy: 0.7248, Train AUC: 0.7971, Valid AUC: 0.8012
# Features: ('col_1', 'col_5', 'col_6', 'col_7'), Train Accuracy: 0.7204, Valid Accuracy: 0.7247, Train AUC: 0.7971, Valid AUC: 0.8012
# Features: ('col_1', 'col_4', 'col_6', 'col_7'), Train Accuracy: 0.7206, Valid Accuracy: 0.7249, Train AUC: 0.7971, Valid AUC: 0.8011
# Features: ('col_1', 'col_6', 'col_7'), Train Accuracy: 0.7206, Valid Accuracy: 0.7250, Train AUC: 0.7971, Valid AUC: 0.8012
# Features: ('col_1', 'col_4', 'col_5', 'col_6', 'col_8'), Train Accuracy: 0.7185, Valid Accuracy: 0.7220, Train AUC: 0.7970, Valid AUC: 0.7973
# Features: ('col_1', 'col_5', 'col_6', 'col_8'), Train Accuracy: 0.7183, Valid Accuracy: 0.7225, Train AUC: 0.7970, Valid AUC: 0.7973
# Features: ('col_1', 'col_4', 'col_6', 'col_8'), Train Accuracy: 0.7185, Valid Accuracy: 0.7220, Train AUC: 0.7970, Valid AUC: 0.7973
# Features: ('col_1', 'col_6', 'col_8'), Train Accuracy: 0.7185, Valid Accuracy: 0.7222, Train AUC: 0.7970, Valid AUC: 0.7973
# Features: ('col_1', 'col_3', 'col_4', 'col_5', 'col_8'), Train Accuracy: 0.7203, Valid Accuracy: 0.7192, Train AUC: 0.7968, Valid AUC: 0.7964
# Features: ('col_1', 'col_3', 'col_4', 'col_8'), Train Accuracy: 0.7204, Valid Accuracy: 0.7195, Train AUC: 0.7968, Valid AUC: 0.7964
# Features: ('col_1', 'col_3', 'col_5', 'col_8'), Train Accuracy: 0.7203, Valid Accuracy: 0.7197, Train AUC: 0.7968, Valid AUC: 0.7964
# Features: ('col_1', 'col_3', 'col_8'), Train Accuracy: 0.7202, Valid Accuracy: 0.7195, Train AUC: 0.7968, Valid AUC: 0.7964
# Features: ('col_1', 'col_3', 'col_4', 'col_5', 'col_7'), Train Accuracy: 0.7193, Valid Accuracy: 0.7244, Train AUC: 0.7967, Valid AUC: 0.8017
# Features: ('col_1', 'col_3', 'col_5', 'col_7'), Train Accuracy: 0.7193, Valid Accuracy: 0.7244, Train AUC: 0.7967, Valid AUC: 0.8017
# Features: ('col_1', 'col_3', 'col_4', 'col_7'), Train Accuracy: 0.7192, Valid Accuracy: 0.7242, Train AUC: 0.7967, Valid AUC: 0.8016
# Features: ('col_1', 'col_3', 'col_7'), Train Accuracy: 0.7193, Valid Accuracy: 0.7240, Train AUC: 0.7967, Valid AUC: 0.8016
# Features: ('col_2', 'col_4', 'col_5', 'col_8'), Train Accuracy: 0.7071, Valid Accuracy: 0.7044, Train AUC: 0.7837, Valid AUC: 0.7757
# Features: ('col_2', 'col_4', 'col_8'), Train Accuracy: 0.7071, Valid Accuracy: 0.7043, Train AUC: 0.7837, Valid AUC: 0.7757
# Features: ('col_2', 'col_5', 'col_8'), Train Accuracy: 0.7073, Valid Accuracy: 0.7045, Train AUC: 0.7837, Valid AUC: 0.7757
# Features: ('col_2', 'col_8'), Train Accuracy: 0.7073, Valid Accuracy: 0.7042, Train AUC: 0.7837, Valid AUC: 0.7757
# Features: ('col_2', 'col_4', 'col_5', 'col_7'), Train Accuracy: 0.7073, Valid Accuracy: 0.7096, Train AUC: 0.7828, Valid AUC: 0.7847
# Features: ('col_2', 'col_5', 'col_7'), Train Accuracy: 0.7073, Valid Accuracy: 0.7096, Train AUC: 0.7828, Valid AUC: 0.7847
# Features: ('col_2', 'col_7'), Train Accuracy: 0.7073, Valid Accuracy: 0.7098, Train AUC: 0.7828, Valid AUC: 0.7846
# Features: ('col_2', 'col_4', 'col_7'), Train Accuracy: 0.7073, Valid Accuracy: 0.7098, Train AUC: 0.7828, Valid AUC: 0.7846
# Features: ('col_1', 'col_2', 'col_4'), Train Accuracy: 0.7078, Valid Accuracy: 0.7112, Train AUC: 0.7822, Valid AUC: 0.7860
# Features: ('col_1', 'col_2', 'col_4', 'col_5'), Train Accuracy: 0.7078, Valid Accuracy: 0.7109, Train AUC: 0.7822, Valid AUC: 0.7860
# Features: ('col_1', 'col_2'), Train Accuracy: 0.7079, Valid Accuracy: 0.7110, Train AUC: 0.7822, Valid AUC: 0.7860
# Features: ('col_1', 'col_2', 'col_5'), Train Accuracy: 0.7079, Valid Accuracy: 0.7115, Train AUC: 0.7822, Valid AUC: 0.7860
# Features: ('col_5', 'col_7', 'col_8'), Train Accuracy: 0.7061, Valid Accuracy: 0.7070, Train AUC: 0.7808, Valid AUC: 0.7773
# Features: ('col_4', 'col_5', 'col_7', 'col_8'), Train Accuracy: 0.7060, Valid Accuracy: 0.7070, Train AUC: 0.7808, Valid AUC: 0.7773
# Features: ('col_7', 'col_8'), Train Accuracy: 0.7062, Valid Accuracy: 0.7069, Train AUC: 0.7808, Valid AUC: 0.7773
# Features: ('col_4', 'col_7', 'col_8'), Train Accuracy: 0.7063, Valid Accuracy: 0.7068, Train AUC: 0.7808, Valid AUC: 0.7773
# Features: ('col_1', 'col_4', 'col_5', 'col_7'), Train Accuracy: 0.7075, Valid Accuracy: 0.7095, Train AUC: 0.7803, Valid AUC: 0.7847
# Features: ('col_1', 'col_4', 'col_7'), Train Accuracy: 0.7075, Valid Accuracy: 0.7097, Train AUC: 0.7803, Valid AUC: 0.7846
# Features: ('col_1', 'col_5', 'col_7'), Train Accuracy: 0.7075, Valid Accuracy: 0.7094, Train AUC: 0.7803, Valid AUC: 0.7847
# Features: ('col_1', 'col_7'), Train Accuracy: 0.7075, Valid Accuracy: 0.7096, Train AUC: 0.7803, Valid AUC: 0.7846
# Features: ('col_1', 'col_4', 'col_5', 'col_8'), Train Accuracy: 0.7040, Valid Accuracy: 0.7083, Train AUC: 0.7796, Valid AUC: 0.7798
# Features: ('col_1', 'col_4', 'col_8'), Train Accuracy: 0.7038, Valid Accuracy: 0.7079, Train AUC: 0.7796, Valid AUC: 0.7798
# Features: ('col_1', 'col_5', 'col_8'), Train Accuracy: 0.7039, Valid Accuracy: 0.7086, Train AUC: 0.7796, Valid AUC: 0.7798
# Features: ('col_1', 'col_8'), Train Accuracy: 0.7042, Valid Accuracy: 0.7084, Train AUC: 0.7796, Valid AUC: 0.7798
# Features: ('col_2', 'col_3', 'col_5', 'col_6'), Train Accuracy: 0.6784, Valid Accuracy: 0.6791, Train AUC: 0.7423, Valid AUC: 0.7414
# Features: ('col_2', 'col_3', 'col_4', 'col_5', 'col_6'), Train Accuracy: 0.6784, Valid Accuracy: 0.6791, Train AUC: 0.7423, Valid AUC: 0.7414
# Features: ('col_2', 'col_3', 'col_6'), Train Accuracy: 0.6784, Valid Accuracy: 0.6791, Train AUC: 0.7423, Valid AUC: 0.7413
# Features: ('col_2', 'col_3', 'col_4', 'col_6'), Train Accuracy: 0.6785, Valid Accuracy: 0.6792, Train AUC: 0.7423, Valid AUC: 0.7413
# Features: ('col_3', 'col_5', 'col_6', 'col_8'), Train Accuracy: 0.6758, Valid Accuracy: 0.6700, Train AUC: 0.7402, Valid AUC: 0.7340
# Features: ('col_3', 'col_4', 'col_5', 'col_6', 'col_8'), Train Accuracy: 0.6758, Valid Accuracy: 0.6703, Train AUC: 0.7402, Valid AUC: 0.7340
# Features: ('col_3', 'col_6', 'col_8'), Train Accuracy: 0.6760, Valid Accuracy: 0.6700, Train AUC: 0.7402, Valid AUC: 0.7340
# Features: ('col_3', 'col_4', 'col_6', 'col_8'), Train Accuracy: 0.6760, Valid Accuracy: 0.6703, Train AUC: 0.7402, Valid AUC: 0.7340
# Features: ('col_3', 'col_4', 'col_5', 'col_6', 'col_7'), Train Accuracy: 0.6772, Valid Accuracy: 0.6796, Train AUC: 0.7391, Valid AUC: 0.7441
# Features: ('col_3', 'col_4', 'col_6', 'col_7'), Train Accuracy: 0.6773, Valid Accuracy: 0.6803, Train AUC: 0.7391, Valid AUC: 0.7440
# Features: ('col_3', 'col_5', 'col_6', 'col_7'), Train Accuracy: 0.6770, Valid Accuracy: 0.6801, Train AUC: 0.7391, Valid AUC: 0.7441
# Features: ('col_3', 'col_6', 'col_7'), Train Accuracy: 0.6775, Valid Accuracy: 0.6802, Train AUC: 0.7391, Valid AUC: 0.7440
# Features: ('col_1', 'col_3', 'col_4', 'col_5', 'col_6'), Train Accuracy: 0.6754, Valid Accuracy: 0.6768, Train AUC: 0.7384, Valid AUC: 0.7433
# Features: ('col_1', 'col_3', 'col_5', 'col_6'), Train Accuracy: 0.6754, Valid Accuracy: 0.6772, Train AUC: 0.7384, Valid AUC: 0.7433
# Features: ('col_1', 'col_3', 'col_4', 'col_6'), Train Accuracy: 0.6755, Valid Accuracy: 0.6768, Train AUC: 0.7384, Valid AUC: 0.7432
# Features: ('col_1', 'col_3', 'col_6'), Train Accuracy: 0.6754, Valid Accuracy: 0.6768, Train AUC: 0.7384, Valid AUC: 0.7432
# Features: ('col_2', 'col_5', 'col_6'), Train Accuracy: 0.6667, Valid Accuracy: 0.6644, Train AUC: 0.7232, Valid AUC: 0.7199
# Features: ('col_2', 'col_4', 'col_5', 'col_6'), Train Accuracy: 0.6666, Valid Accuracy: 0.6646, Train AUC: 0.7232, Valid AUC: 0.7199
# Features: ('col_2', 'col_6'), Train Accuracy: 0.6667, Valid Accuracy: 0.6640, Train AUC: 0.7232, Valid AUC: 0.7198
# Features: ('col_2', 'col_4', 'col_6'), Train Accuracy: 0.6667, Valid Accuracy: 0.6640, Train AUC: 0.7232, Valid AUC: 0.7198
# Features: ('col_2', 'col_3', 'col_4', 'col_5'), Train Accuracy: 0.6665, Valid Accuracy: 0.6641, Train AUC: 0.7227, Valid AUC: 0.7204
# Features: ('col_2', 'col_3'), Train Accuracy: 0.6665, Valid Accuracy: 0.6641, Train AUC: 0.7227, Valid AUC: 0.7204
# Features: ('col_2', 'col_3', 'col_5'), Train Accuracy: 0.6664, Valid Accuracy: 0.6640, Train AUC: 0.7227, Valid AUC: 0.7204
# Features: ('col_2', 'col_3', 'col_4'), Train Accuracy: 0.6665, Valid Accuracy: 0.6642, Train AUC: 0.7227, Valid AUC: 0.7204
# Features: ('col_5', 'col_6', 'col_8'), Train Accuracy: 0.6646, Valid Accuracy: 0.6564, Train AUC: 0.7202, Valid AUC: 0.7127
# Features: ('col_4', 'col_5', 'col_6', 'col_8'), Train Accuracy: 0.6646, Valid Accuracy: 0.6565, Train AUC: 0.7202, Valid AUC: 0.7127
# Features: ('col_6', 'col_8'), Train Accuracy: 0.6645, Valid Accuracy: 0.6562, Train AUC: 0.7202, Valid AUC: 0.7127
# Features: ('col_4', 'col_6', 'col_8'), Train Accuracy: 0.6645, Valid Accuracy: 0.6562, Train AUC: 0.7202, Valid AUC: 0.7127
# Features: ('col_4', 'col_5', 'col_6', 'col_7'), Train Accuracy: 0.6633, Valid Accuracy: 0.6657, Train AUC: 0.7199, Valid AUC: 0.7238
# Features: ('col_5', 'col_6', 'col_7'), Train Accuracy: 0.6634, Valid Accuracy: 0.6659, Train AUC: 0.7199, Valid AUC: 0.7238
# Features: ('col_4', 'col_6', 'col_7'), Train Accuracy: 0.6635, Valid Accuracy: 0.6654, Train AUC: 0.7199, Valid AUC: 0.7237
# Features: ('col_6', 'col_7'), Train Accuracy: 0.6637, Valid Accuracy: 0.6656, Train AUC: 0.7199, Valid AUC: 0.7237
# Features: ('col_3', 'col_4', 'col_5', 'col_8'), Train Accuracy: 0.6632, Valid Accuracy: 0.6552, Train AUC: 0.7197, Valid AUC: 0.7124
# Features: ('col_3', 'col_5', 'col_8'), Train Accuracy: 0.6632, Valid Accuracy: 0.6552, Train AUC: 0.7197, Valid AUC: 0.7125
# Features: ('col_3', 'col_8'), Train Accuracy: 0.6632, Valid Accuracy: 0.6551, Train AUC: 0.7197, Valid AUC: 0.7124
# Features: ('col_3', 'col_4', 'col_8'), Train Accuracy: 0.6632, Valid Accuracy: 0.6550, Train AUC: 0.7197, Valid AUC: 0.7124
# Features: ('col_3', 'col_4', 'col_5', 'col_7'), Train Accuracy: 0.6633, Valid Accuracy: 0.6700, Train AUC: 0.7191, Valid AUC: 0.7239
# Features: ('col_3', 'col_5', 'col_7'), Train Accuracy: 0.6632, Valid Accuracy: 0.6698, Train AUC: 0.7191, Valid AUC: 0.7239
# Features: ('col_3', 'col_4', 'col_7'), Train Accuracy: 0.6632, Valid Accuracy: 0.6696, Train AUC: 0.7191, Valid AUC: 0.7239
# Features: ('col_3', 'col_7'), Train Accuracy: 0.6632, Valid Accuracy: 0.6696, Train AUC: 0.7191, Valid AUC: 0.7239
# Features: ('col_1', 'col_4', 'col_5', 'col_6'), Train Accuracy: 0.6630, Valid Accuracy: 0.6655, Train AUC: 0.7187, Valid AUC: 0.7238
# Features: ('col_1', 'col_5', 'col_6'), Train Accuracy: 0.6627, Valid Accuracy: 0.6653, Train AUC: 0.7187, Valid AUC: 0.7238
# Features: ('col_1', 'col_4', 'col_6'), Train Accuracy: 0.6628, Valid Accuracy: 0.6648, Train AUC: 0.7187, Valid AUC: 0.7237
# Features: ('col_1', 'col_6'), Train Accuracy: 0.6626, Valid Accuracy: 0.6645, Train AUC: 0.7187, Valid AUC: 0.7238
# Features: ('col_1', 'col_3', 'col_4', 'col_5'), Train Accuracy: 0.6612, Valid Accuracy: 0.6670, Train AUC: 0.7183, Valid AUC: 0.7248
# Features: ('col_1', 'col_3', 'col_5'), Train Accuracy: 0.6613, Valid Accuracy: 0.6670, Train AUC: 0.7183, Valid AUC: 0.7248
# Features: ('col_1', 'col_3', 'col_4'), Train Accuracy: 0.6612, Valid Accuracy: 0.6672, Train AUC: 0.7183, Valid AUC: 0.7248
# Features: ('col_1', 'col_3'), Train Accuracy: 0.6613, Valid Accuracy: 0.6675, Train AUC: 0.7183, Valid AUC: 0.7248
# Features: ('col_2', 'col_4', 'col_5'), Train Accuracy: 0.6536, Valid Accuracy: 0.6486, Train AUC: 0.7016, Valid AUC: 0.6974
# Features: ('col_2', 'col_5'), Train Accuracy: 0.6537, Valid Accuracy: 0.6485, Train AUC: 0.7016, Valid AUC: 0.6975
# Features: ('col_2', 'col_4'), Train Accuracy: 0.6537, Valid Accuracy: 0.6485, Train AUC: 0.7016, Valid AUC: 0.6974
# Features: ('col_2',), Train Accuracy: 0.6535, Valid Accuracy: 0.6484, Train AUC: 0.7016, Valid AUC: 0.6974
# Features: ('col_5', 'col_7'), Train Accuracy: 0.6515, Valid Accuracy: 0.6517, Train AUC: 0.6978, Valid AUC: 0.7013
# Features: ('col_4', 'col_5', 'col_7'), Train Accuracy: 0.6515, Valid Accuracy: 0.6516, Train AUC: 0.6978, Valid AUC: 0.7013
# Features: ('col_7',), Train Accuracy: 0.6514, Valid Accuracy: 0.6521, Train AUC: 0.6978, Valid AUC: 0.7013
# Features: ('col_4', 'col_7'), Train Accuracy: 0.6515, Valid Accuracy: 0.6520, Train AUC: 0.6978, Valid AUC: 0.7013
# Features: ('col_4', 'col_5', 'col_8'), Train Accuracy: 0.6497, Valid Accuracy: 0.6431, Train AUC: 0.6978, Valid AUC: 0.6886
# Features: ('col_5', 'col_8'), Train Accuracy: 0.6497, Valid Accuracy: 0.6431, Train AUC: 0.6978, Valid AUC: 0.6886
# Features: ('col_4', 'col_8'), Train Accuracy: 0.6497, Valid Accuracy: 0.6432, Train AUC: 0.6978, Valid AUC: 0.6886
# Features: ('col_8',), Train Accuracy: 0.6496, Valid Accuracy: 0.6432, Train AUC: 0.6978, Valid AUC: 0.6886
# Features: ('col_1', 'col_4', 'col_5'), Train Accuracy: 0.6484, Valid Accuracy: 0.6546, Train AUC: 0.6968, Valid AUC: 0.7033
# Features: ('col_1', 'col_5'), Train Accuracy: 0.6484, Valid Accuracy: 0.6545, Train AUC: 0.6968, Valid AUC: 0.7033
# Features: ('col_1', 'col_4'), Train Accuracy: 0.6482, Valid Accuracy: 0.6544, Train AUC: 0.6968, Valid AUC: 0.7033
# Features: ('col_1',), Train Accuracy: 0.6482, Valid Accuracy: 0.6541, Train AUC: 0.6968, Valid AUC: 0.7033
# Features: ('col_3', 'col_5', 'col_6'), Train Accuracy: 0.5944, Valid Accuracy: 0.5985, Train AUC: 0.6333, Valid AUC: 0.6370
# Features: ('col_3', 'col_4', 'col_5', 'col_6'), Train Accuracy: 0.5945, Valid Accuracy: 0.5983, Train AUC: 0.6333, Valid AUC: 0.6370
# Features: ('col_3', 'col_6'), Train Accuracy: 0.5943, Valid Accuracy: 0.5982, Train AUC: 0.6333, Valid AUC: 0.6370
# Features: ('col_3', 'col_4', 'col_6'), Train Accuracy: 0.5945, Valid Accuracy: 0.5985, Train AUC: 0.6333, Valid AUC: 0.6370
# Features: ('col_4', 'col_5', 'col_6'), Train Accuracy: 0.5726, Valid Accuracy: 0.5736, Train AUC: 0.5957, Valid AUC: 0.5969
# Features: ('col_5', 'col_6'), Train Accuracy: 0.5725, Valid Accuracy: 0.5729, Train AUC: 0.5957, Valid AUC: 0.5969
# Features: ('col_4', 'col_6'), Train Accuracy: 0.5723, Valid Accuracy: 0.5737, Train AUC: 0.5957, Valid AUC: 0.5968
# Features: ('col_6',), Train Accuracy: 0.5722, Valid Accuracy: 0.5737, Train AUC: 0.5957, Valid AUC: 0.5968
# Features: ('col_3', 'col_5'), Train Accuracy: 0.5714, Valid Accuracy: 0.5723, Train AUC: 0.5948, Valid AUC: 0.5985
# Features: ('col_3', 'col_4', 'col_5'), Train Accuracy: 0.5715, Valid Accuracy: 0.5723, Train AUC: 0.5948, Valid AUC: 0.5985
# Features: ('col_3', 'col_4'), Train Accuracy: 0.5712, Valid Accuracy: 0.5723, Train AUC: 0.5947, Valid AUC: 0.5984
# Features: ('col_3',), Train Accuracy: 0.5712, Valid Accuracy: 0.5724, Train AUC: 0.5947, Valid AUC: 0.5984
# Features: ('col_4', 'col_5'), Train Accuracy: 0.5019, Valid Accuracy: 0.5103, Train AUC: 0.5019, Valid AUC: 0.5075
# Features: ('col_5',), Train Accuracy: 0.5024, Valid Accuracy: 0.5099, Train AUC: 0.5019, Valid AUC: 0.5078
# Features: ('col_4',), Train Accuracy: 0.5027, Valid Accuracy: 0.5100, Train AUC: 0.5003, Valid AUC: 0.4979

# %%
# Initialize the client
client = MlflowClient()

# Get the experiment ID by name
experiment = client.get_experiment_by_name(settings['mlflow_experiment_name'])
if experiment is None:
    raise ValueError(f"Experiment with name '{experiment_name}' not found")

experiment_id = experiment.experiment_id

# List all runs in the experiment
runs = client.search_runs(experiment_ids=[experiment_id])

# %%
# Function to flatten the RunData dictionary
def flatten_rundata(run_data):
    flat_data = {}
    flat_data.update(run_data.data.metrics)
    flat_data.update(run_data.data.params)
    flat_data['run_name'] = run_data.data.tags['mlflow.runName']

    use_col_count = sum(1 for key, value in run_data.data.params.items() if 'use_col_' in key and value == 'True')
    flat_data['n_vars'] = use_col_count
    return flat_data

# Flatten all RunData dictionaries
flattened_data = [flatten_rundata(run) for run in runs]

# Convert to DataFrame
df = pd.DataFrame(flattened_data)

# Display the DataFrame
print(df)
# Out:
#      train_accuracy  valid_accuracy  train_auc  valid_auc use_col_1 use_col_2  \
# 0          0.847017         0.84805   0.939422   0.940125      True      True
# 1          0.793267         0.79140   0.880264   0.878690     False      True
# 2          0.790733         0.79005   0.878273   0.877857      True     False
# 3          0.834750         0.83665   0.925614   0.926351      True      True
# 4          0.847033         0.84805   0.939422   0.940125      True      True
# ..              ...             ...        ...        ...       ...       ...
# 250        0.502433         0.50985   0.501855   0.507830     False     False
# 251        0.502733         0.51000   0.500265   0.497897     False     False
# 252        0.571217         0.57235   0.594743   0.598441     False     False
# 253        0.653533         0.64845   0.701612   0.697410     False      True
# 254        0.648200         0.65405   0.696769   0.703276      True     False
#
#     use_col_3 use_col_4 use_col_7 use_col_8 use_col_5 use_col_6  \
# 0        True      True      True      True      True      True
# 1        True      True      True      True      True      True
# 2        True      True      True      True      True      True
# 3       False      True      True      True      True      True
# 4        True     False      True      True      True      True
# ..        ...       ...       ...       ...       ...       ...
# 250     False     False     False     False      True     False
# 251     False      True     False     False     False     False
# 252      True     False     False     False     False     False
# 253     False     False     False     False     False     False
# 254     False     False     False     False     False     False
#
#                  run_name  n_vars
# 0        classy-snake-860       8
# 1       treasured-owl-850       7
# 2        vaunted-bird-218       7
# 3          bright-bat-559       7
# 4          brawny-eel-405       7
# ..                    ...     ...
# 250      salty-shrike-682       1
# 251  entertaining-ray-176       1
# 252         clean-yak-125       1
# 253      exultant-jay-454       1
# 254    grandiose-colt-192       1
#
# [255 rows x 14 columns]

# %%
# Group by 'n_vars' and get the indices of the rows with the highest 'valid_auc' within each group
idx = df.groupby('n_vars')['valid_auc'].idxmax()

# Use these indices to filter the DataFrame
df_highest_valid_auc = df.loc[idx].reset_index(drop=True)

# Display the resulting DataFrame
print(df_highest_valid_auc)
# Out:
#    train_accuracy  valid_accuracy  train_auc  valid_auc use_col_1 use_col_2  \
# 0        0.648200         0.65405   0.696769   0.703276      True     False
# 1        0.707950         0.71100   0.782236   0.785957      True      True
# 2        0.764767         0.76920   0.849540   0.853760      True      True
# 3        0.821933         0.82380   0.911628   0.911659      True      True
# 4        0.835000         0.83660   0.925609   0.926338      True      True
# 5        0.847033         0.84795   0.939420   0.940117      True      True
# 6        0.847033         0.84805   0.939422   0.940125      True      True
# 7        0.847017         0.84805   0.939422   0.940125      True      True
#
#   use_col_3 use_col_4 use_col_7 use_col_8 use_col_5 use_col_6  \
# 0     False     False     False     False     False     False
# 1     False     False     False     False     False     False
# 2     False     False      True     False     False     False
# 3     False     False      True      True     False     False
# 4     False     False      True      True     False      True
# 5      True     False      True      True     False      True
# 6      True     False      True      True      True      True
# 7      True      True      True      True      True      True
#
#              run_name  n_vars
# 0  grandiose-colt-192       1
# 1  dazzling-midge-591       2
# 2     rogue-mouse-615       3
# 3    dazzling-fly-876       4
# 4       calm-gull-488       5
# 5        loud-doe-899       6
# 6      brawny-eel-405       7
# 7    classy-snake-860       8

# %%
vars_best_iteration = ["col_1", "col_2", "col_3", "col_6", "col_7", "col_8"]
feature_columns = [col for col in train_df.columns if col != target_column]

with mlflow.start_run(run_name = "best-valid-auc-6-vars"):
    model = LogisticRegression(max_iter=1000, random_state=42)
    model.fit(train_df[vars_best_iteration], train_df[target_column])

    train_predictions = model.predict(train_df[vars_best_iteration])
    valid_predictions = model.predict(valid_df[vars_best_iteration])

    train_accuracy = accuracy_score(train_df[target_column], train_predictions)
    valid_accuracy = accuracy_score(valid_df[target_column], valid_predictions)

    train_predictions_proba = model.predict_proba(train_df[vars_best_iteration])[:, 1]
    valid_predictions_proba = model.predict_proba(valid_df[vars_best_iteration])[:, 1]
    
    train_auc = roc_auc_score(train_df[target_column], train_predictions_proba)
    valid_auc = roc_auc_score(valid_df[target_column], valid_predictions_proba)

    # Log parameters: which variables are used
    for col in feature_columns:
        mlflow.log_param(f"use_{col}", col in vars_best_iteration)

    # Log metrics
    mlflow.log_metric("train_accuracy", train_accuracy)
    mlflow.log_metric("valid_accuracy", valid_accuracy)
    mlflow.log_metric("train_auc", train_auc)
    mlflow.log_metric("valid_auc", valid_auc)

# %%
base_s3_path = settings['project_path_s3']
paths = {
    'train_pred': f"{base_s3_path}/output/base_pred/train.csv",
    'valid_pred': f"{base_s3_path}/output/base_pred/valid.csv",
}

df_train_predictions_proba = pd.DataFrame(train_predictions_proba, columns=['pred'])
df_train_predictions_proba['target'] = train_df['target']
df_valid_predictions_proba = pd.DataFrame(valid_predictions_proba, columns=['pred'])
df_valid_predictions_proba['target'] = valid_df['target']

save_df_to_s3(df_train_predictions_proba, settings['bucket_name'], paths['train_pred'], decimal_places = 5)
save_df_to_s3(df_valid_predictions_proba, settings['bucket_name'], paths['valid_pred'], decimal_places = 5)

# %%
# !aws s3api get-object --bucket {settings['bucket_name']} --key {paths['train_pred']} /dev/stdout | head -n 10
# Out:
# pred,target
# 0.99987,1
# 0.99387,1
# 0.07881,0
# 0.01232,0
# 0.57458,1
# 0.03212,0
# 0.99525,1
# 0.96508,1
# 0.83500,1
#
# [Errno 32] Broken pipe

# %%
# !aws s3api get-object --bucket {settings['bucket_name']} --key {paths['valid_pred']} /dev/stdout | head -n 10
# Out:
# pred,target
# 0.00512,0
# 0.49614,0
# 0.10881,0
# 0.15601,0
# 0.89603,1
# 0.46593,1
# 0.18065,0
# 0.07806,0
# 0.50506,1
#
# [Errno 32] Broken pipe
