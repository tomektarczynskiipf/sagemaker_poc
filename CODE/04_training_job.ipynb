# %%
from functions import *

import os
import pandas as pd
import numpy as np
import sagemaker

from sagemaker.sklearn.estimator import SKLearn
from sagemaker import get_execution_role

settings = read_settings()
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
os.makedirs("training_script", exist_ok=True) # Create folder for training code

# %%
# %%writefile training_script/requirements.txt
#
# mlflow==2.13.2
# sagemaker-mlflow==0.1.0
# Out:
# Overwriting training_script/requirements.txt

# %%
# %%writefile training_script/train.py

from __future__ import print_function

import argparse
import joblib
import os
import pandas as pd
import tarfile
from sklearn.linear_model import LogisticRegression
import mlflow
import shutil

if __name__ == '__main__':
    model_dir = os.environ['SM_MODEL_DIR'] # Folder where model must be saved
    train_dir = os.environ['SM_CHANNEL_TRAIN'] # Folder where train data is stored
    output_dir = os.environ['SM_OUTPUT_DATA_DIR']

    # Lets assume there is only one training file
    train_file_name = os.listdir(train_dir)[0]
    train_file_path = os.path.join(train_dir, train_file_name)
    
    train_data = pd.read_csv(train_file_path, engine="python")

    # labels are in the first column
    train_y = train_data.iloc[:, 0]
    train_X = train_data.iloc[:, 1:]  

    mlflow.set_tracking_uri(os.environ['mlflow_arn'])
    mlflow.set_experiment(os.environ['mlflow_experiment_name'])
    
    with mlflow.start_run(run_name = os.environ['mlflow_final_model_name']):
        mlflow.set_tag("training_job_name", os.environ['TRAINING_JOB_NAME'])
        
        clf = LogisticRegression(max_iter=100)
        clf = clf.fit(train_X, train_y)
    
        mlflow.sklearn.log_model(clf, "model")

        model_path = os.path.join(model_dir, "model.pkl")
        joblib.dump(clf, model_path)
    

        # Pack model.pkl into model.tar.gz
        tar_path = os.path.join(output_dir, "model.tar.gz")
        with tarfile.open(tar_path, "w:gz") as tar:
            tar.add(model_path, arcname=os.path.basename(model_path))

        # Log the model.tar.gz as an artifact in MLflow
        mlflow.log_artifact(tar_path, artifact_path="model")
        os.remove(tar_path)

    # Register the model with MLflow
    run_id = mlflow.last_active_run().info.run_id
    artifact_path = "model"
    model_uri = "runs:/{run_id}/{artifact_path}".format(run_id=run_id, artifact_path=artifact_path)
    model_details = mlflow.register_model(model_uri=model_uri, name=os.environ['mlflow_model_name'])
# Out:
# Overwriting training_script/train.py

# %%
role = get_execution_role()
sagemaker_session = sagemaker.Session()

# %%
environment = {
    'mlflow_arn': settings['mlflow_arn'],
    'mlflow_experiment_name': settings['mlflow_experiment_name'],
    'mlflow_final_model_name': 'final-model2',
    'mlflow_model_name': settings['mlflow_model_name']
}

sklearn = SKLearn(
    entry_point='train.py', # The file with the training code
    source_dir='training_script', # The folder with the training code
    framework_version='1.2-1', # Version of SKLearn which will be used
    instance_type='ml.m5.large', # Instance type that wil be used
    role=role, # Role that will be used during execution
    sagemaker_session=sagemaker_session, 
    base_job_name=settings['training_job_name'], # Name of the training job. Timestamp will be added as suffix
    environment = environment
)

# %%
# Read the train and validation data from S3
train_s3_key = f"{settings['project_path_s3']}/data/train/train.csv"

train_df = read_csv_from_s3(settings['bucket_name'], train_s3_key)

train_df = train_df[['target', "col_1", "col_2", "col_3", "col_6", "col_7", "col_8"]]

s3_key = f"{settings['project_path_s3']}/data/train_job/train.csv"
save_df_to_s3(df = train_df, bucket_name = settings['bucket_name'], s3_key = s3_key, decimal_places = 5)

# %%
sklearn.fit({"train": f"s3://{settings['bucket_name']}/{settings['project_path_s3']}/data/train_job/"})
# Out:
# INFO:sagemaker:Creating training-job with name: 01-churn-2024-07-12-14-06-35-035
# 2024-07-12 14:06:35 Starting - Starting the training job...
# 2024-07-12 14:06:53 Starting - Preparing the instances for training...
# 2024-07-12 14:07:18 Downloading - Downloading input data...
# 2024-07-12 14:07:43 Downloading - Downloading the training image......
# 2024-07-12 14:08:43 Training - Training image download completed. Training in progress.2024-07-12 14:08:48,162 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2024-07-12 14:08:48,166 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-07-12 14:08:48,170 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-07-12 14:08:48,260 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2024-07-12 14:08:48,499 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Collecting mlflow==2.13.2 (from -r requirements.txt (line 2))
#   Downloading mlflow-2.13.2-py3-none-any.whl.metadata (29 kB)
# Collecting sagemaker-mlflow==0.1.0 (from -r requirements.txt (line 3))
#   Downloading sagemaker_mlflow-0.1.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: Flask<4 in /miniconda3/lib/python3.8/site-packages (from mlflow==2.13.2->-r requirements.txt (line 2)) (1.1.1)
# Collecting alembic!=1.10.0,<2 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting cachetools<6,>=5.0.0 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in /miniconda3/lib/python3.8/site-packages (from mlflow==2.13.2->-r requirements.txt (line 2)) (8.1.7)
# Collecting cloudpickle<4 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting docker<8,>=4.0.0 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting entrypoints<1 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting graphene<4 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading graphene-3.3-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting importlib-metadata!=4.7.0,<8,>=3.7.0 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading importlib_metadata-7.2.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting markdown<4,>=3.3 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting matplotlib<4 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy<2 in /miniconda3/lib/python3.8/site-packages (from mlflow==2.13.2->-r requirements.txt (line 2)) (1.24.1)
# Collecting opentelemetry-api<3,>=1.0.0 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading opentelemetry_api-1.25.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-sdk<3,>=1.0.0 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading opentelemetry_sdk-1.25.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting packaging<25 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas<3 in /miniconda3/lib/python3.8/site-packages (from mlflow==2.13.2->-r requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /miniconda3/lib/python3.8/site-packages (from mlflow==2.13.2->-r requirements.txt (line 2)) (3.20.2)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /miniconda3/lib/python3.8/site-packages (from mlflow==2.13.2->-r requirements.txt (line 2)) (14.0.1)
# Requirement already satisfied: pytz<2025 in /miniconda3/lib/python3.8/site-packages (from mlflow==2.13.2->-r requirements.txt (line 2)) (2024.1)
# Collecting pyyaml<7,>=5.1 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting querystring-parser<2 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl.metadata (559 bytes)
# Requirement already satisfied: requests<3,>=2.17.3 in /miniconda3/lib/python3.8/site-packages (from mlflow==2.13.2->-r requirements.txt (line 2)) (2.32.2)
# Requirement already satisfied: scikit-learn<2 in /miniconda3/lib/python3.8/site-packages (from mlflow==2.13.2->-r requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: scipy<2 in /miniconda3/lib/python3.8/site-packages (from mlflow==2.13.2->-r requirements.txt (line 2)) (1.8.0)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading SQLAlchemy-2.0.31-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading sqlparse-0.5.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: Jinja2<4,>=2.11 in /miniconda3/lib/python3.8/site-packages (from mlflow==2.13.2->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: gunicorn<23 in /miniconda3/lib/python3.8/site-packages (from mlflow==2.13.2->-r requirements.txt (line 2)) (20.0.4)
# Collecting boto3>=1.34 (from sagemaker-mlflow==0.1.0->-r requirements.txt (line 3))
#   Downloading boto3-1.34.143-py3-none-any.whl.metadata (6.6 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4 (from alembic!=1.10.0,<2->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting importlib-resources (from alembic!=1.10.0,<2->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting botocore<1.35.0,>=1.34.143 (from boto3>=1.34->sagemaker-mlflow==0.1.0->-r requirements.txt (line 3))
#   Downloading botocore-1.34.143-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /miniconda3/lib/python3.8/site-packages (from boto3>=1.34->sagemaker-mlflow==0.1.0->-r requirements.txt (line 3)) (1.0.1)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.34->sagemaker-mlflow==0.1.0->-r requirements.txt (line 3))
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /miniconda3/lib/python3.8/site-packages (from docker<8,>=4.0.0->mlflow==2.13.2->-r requirements.txt (line 2)) (1.26.18)
# Requirement already satisfied: Werkzeug>=0.15 in /miniconda3/lib/python3.8/site-packages (from Flask<4->mlflow==2.13.2->-r requirements.txt (line 2)) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in /miniconda3/lib/python3.8/site-packages (from Flask<4->mlflow==2.13.2->-r requirements.txt (line 2)) (2.0.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading graphql_core-3.2.3-py3-none-any.whl.metadata (10 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting aniso8601<10,>=8 (from graphene<4->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: setuptools>=3.0 in /miniconda3/lib/python3.8/site-packages (from gunicorn<23->mlflow==2.13.2->-r requirements.txt (line 2)) (65.5.1)
# Collecting zipp>=0.5 (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading zipp-3.19.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /miniconda3/lib/python3.8/site-packages (from Jinja2<4,>=2.11->mlflow==2.13.2->-r requirements.txt (line 2)) (2.1.1)
# Collecting contourpy>=1.0.1 (from matplotlib<4->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib<4->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading fonttools-4.53.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 22.8 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib<4->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading kiwisolver-1.4.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: pillow>=6.2.0 in /miniconda3/lib/python3.8/site-packages (from matplotlib<4->mlflow==2.13.2->-r requirements.txt (line 2)) (10.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib<4->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /miniconda3/lib/python3.8/site-packages (from matplotlib<4->mlflow==2.13.2->-r requirements.txt (line 2)) (2.8.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.0.0->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata!=4.7.0,<8,>=3.7.0 (from mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading importlib_metadata-7.1.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting opentelemetry-semantic-conventions==0.46b0 (from opentelemetry-sdk<3,>=1.0.0->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: six in /miniconda3/lib/python3.8/site-packages (from querystring-parser<2->mlflow==2.13.2->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /miniconda3/lib/python3.8/site-packages (from requests<3,>=2.17.3->mlflow==2.13.2->-r requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /miniconda3/lib/python3.8/site-packages (from requests<3,>=2.17.3->mlflow==2.13.2->-r requirements.txt (line 2)) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /miniconda3/lib/python3.8/site-packages (from requests<3,>=2.17.3->mlflow==2.13.2->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in /miniconda3/lib/python3.8/site-packages (from scikit-learn<2->mlflow==2.13.2->-r requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /miniconda3/lib/python3.8/site-packages (from scikit-learn<2->mlflow==2.13.2->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /miniconda3/lib/python3.8/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.13.2->-r requirements.txt (line 2)) (3.0.3)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.6->opentelemetry-api<3,>=1.0.0->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading wrapt-1.16.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow==2.13.2->-r requirements.txt (line 2))
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading mlflow-2.13.2-py3-none-any.whl (25.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 74.8 MB/s eta 0:00:00
# Downloading sagemaker_mlflow-0.1.0-py3-none-any.whl (24 kB)
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 39.4 MB/s eta 0:00:00
# Downloading boto3-1.34.143-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 26.5 MB/s eta 0:00:00
# Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 31.8 MB/s eta 0:00:00
# Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 40.6 MB/s eta 0:00:00
# Downloading graphene-3.3-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 28.4 MB/s eta 0:00:00
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 23.8 MB/s eta 0:00:00
# Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 126.1 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.25.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 14.4 MB/s eta 0:00:00
# Downloading importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Downloading opentelemetry_sdk-1.25.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 25.6 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 31.3 MB/s eta 0:00:00
# Downloading packaging-24.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 13.0 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (736 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 736.6/736.6 kB 86.4 MB/s eta 0:00:00
# Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Downloading SQLAlchemy-2.0.31-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 127.9 MB/s eta 0:00:00
# Downloading sqlparse-0.5.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 10.0 MB/s eta 0:00:00
# Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 12.8 MB/s eta 0:00:00
# Downloading botocore-1.34.143-py3-none-any.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 121.7 MB/s eta 0:00:00
# Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.1/301.1 kB 54.6 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading fonttools-4.53.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 122.3 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 15.1 MB/s eta 0:00:00
# Downloading graphql_core-3.2.3-py3-none-any.whl (202 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 42.6 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Downloading kiwisolver-1.4.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 101.2 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 25.4 MB/s eta 0:00:00
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 17.4 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading zipp-3.19.2-py3-none-any.whl (9.0 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 20.3 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Downloading wrapt-1.16.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 17.6 MB/s eta 0:00:00
# Installing collected packages: aniso8601, zipp, wrapt, typing-extensions, sqlparse, smmap, querystring-parser, pyyaml, pyparsing, packaging, Mako, kiwisolver, graphql-core, fonttools, entrypoints, cycler, contourpy, cloudpickle, cachetools, sqlalchemy, importlib-resources, importlib-metadata, graphql-relay, gitdb, docker, deprecated, botocore, s3transfer, opentelemetry-api, matplotlib, markdown, graphene, gitpython, alembic, opentelemetry-semantic-conventions, boto3, opentelemetry-sdk, mlflow, sagemaker-mlflow
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.31.85
#     Uninstalling botocore-1.31.85:
#       Successfully uninstalled botocore-1.31.85
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.7.0
#     Uninstalling s3transfer-0.7.0:
#       Successfully uninstalled s3transfer-0.7.0
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.28.57
#     Uninstalling boto3-1.28.57:
#       Successfully uninstalled boto3-1.28.57
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sagemaker-sklearn-container 2.0 requires boto3==1.28.57, but you have boto3 1.34.143 which is incompatible.
# sagemaker-sklearn-container 2.0 requires botocore<1.32.0,>=1.31.57, but you have botocore 1.34.143 which is incompatible.
# Successfully installed Mako-1.3.5 alembic-1.13.2 aniso8601-9.0.1 boto3-1.34.143 botocore-1.34.143 cachetools-5.3.3 cloudpickle-3.0.0 contourpy-1.1.1 cycler-0.12.1 deprecated-1.2.14 docker-7.1.0 entrypoints-0.4 fonttools-4.53.1 gitdb-4.0.11 gitpython-3.1.43 graphene-3.3 graphql-core-3.2.3 graphql-relay-3.2.0 importlib-metadata-7.1.0 importlib-resources-6.4.0 kiwisolver-1.4.5 markdown-3.6 matplotlib-3.7.5 mlflow-2.13.2 opentelemetry-api-1.25.0 opentelemetry-sdk-1.25.0 opentelemetry-semantic-conventions-0.46b0 packaging-24.1 pyparsing-3.1.2 pyyaml-6.0.1 querystring-parser-1.2.4 s3transfer-0.10.2 sagemaker-mlflow-0.1.0 smmap-5.0.1 sqlalchemy-2.0.31 sqlparse-0.5.0 typing-extensions-4.12.2 wrapt-1.16.0 zipp-3.19.2
# 2024-07-12 14:09:04,038 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-07-12 14:09:04,041 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-07-12 14:09:04,062 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-07-12 14:09:04,065 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-07-12 14:09:04,085 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-07-12 14:09:04,088 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-07-12 14:09:04,107 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.m5.large",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.m5.large",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "is_smddprun_installed": false,
#     "job_name": "01-churn-2024-07-12-14-06-35-035",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-eu-west-1-211125740051/01-churn-2024-07-12-14-06-35-035/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.large",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.large",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.m5.large
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-eu-west-1-211125740051/01-churn-2024-07-12-14-06-35-035/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.m5.large","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"is_smddprun_installed":false,"job_name":"01-churn-2024-07-12-14-06-35-035","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-west-1-211125740051/01-churn-2024-07-12-14-06-35-035/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python38.zip:/miniconda3/lib/python3.8:/miniconda3/lib/python3.8/lib-dynload:/miniconda3/lib/python3.8/site-packages
# Invoking script with the following command:
# /miniconda3/bin/python train.py
# 2024-07-12 14:09:04,109 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2024-07-12 14:09:04,110 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# /miniconda3/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Registered model '01-churn' already exists. Creating a new version of this model...
# 2024/07/12 14:09:10 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: 01-churn, version 3
# Created version '3' of model '01-churn'.
# 2024-07-12 14:09:10,527 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2024-07-12 14:09:27 Uploading - Uploading generated training model
# 2024-07-12 14:09:27 Completed - Training job completed
# Training seconds: 129
# Billable seconds: 129
